# %% [markdown]
# ## Problem 1: Print Each Item
#
# Given the list below, print each item on its own line.
#
# Focus:
# - Looping through a list
# - Accessing values

# %%
numbers = [10, 20, 30, 40, 50]

# TODO:
# Print each number on its own line

for number in numbers:
    print(number)
# Out:
# 10
# 20
# 30
# 40
# 50

# %% [markdown]
# ## Problem 2: Collect Even Numbers
#
# Using the list below:
#
# 1. Create a new empty list called `evens`
# 2. Loop through `numbers`
# 3. Add only even numbers to `evens`
# 4. Print the new list
#
# Do not use list comprehensions.

# %%
numbers = [3, 8, 11, 14, 17, 20]

# TODO:
# Create empty list
# Loop
# Append even numbers
# Print result
even_numbers =[]
for number in numbers:
    if number % 2 == 0:
        even_numbers.append(number)
print(even_numbers)
# Out:
# [8, 14, 20]

# %% [markdown]
# ## Problem 3: Replace the Middle Value
#
# Given the list below:
#
# 1. Find the index of the middle element
# 2. Replace that element with the string "REPLACED"
# 3. Print the updated list
#
# Assume the list has an odd number of elements.

# %%
items = ["a", "b", "c", "d", "e"]

# TODO:
# Determine middle index
# Replace value
# Print list

# %% [markdown]
# ## Problem 4: Count Occurrences
#
# Given the list below, count how many times the value 5 appears.
#
# Do not use the built-in `count()` method.

# %%
numbers = [5, 1, 5, 3, 5, 4]

# TODO:
# Create counter variable
# Loop through list
# Increment counter
# Print result
