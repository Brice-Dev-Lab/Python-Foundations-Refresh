# %% [markdown]
# # Function Fundamentals

# %% [markdown]
# ## Coding Challenge #1: The Median Function
#
# ### Objective
# Create a Python function that finds the middle value (the median) of a list of numbers. In professional software development, we don't just care about the result; we care about **data integrity** (not breaking the original data) and **reliability** (handling empty inputs).
#
# ---
#
# ### Technical Requirements
#
# 1.  **Function Name**: `get_median(data)`
# 2.  **Sort the Data**: Your function must work even if the input list is unsorted (e.g., `[5, 1, 3]`).
# 3.  **Handle Empty Input**: If the list is empty, the function should return a helpful error message or `None` rather than crashing the program.
# 4.  **No "Side Effects" (Immutability)**:
#     * **Crucial:** Your function should not change the order of the original list passed into it. Use a method that creates a *sorted copy* instead of sorting the list "in-place."
# 5.  **The "Lesser" Rule for Even Lists**:
#     * If the list has an **odd** number of elements, return the middle one.
#     * If the list has an **even** number of elements, return the **lesser** (lower) of the two middle values.
#     * *Example:* In the sorted list `[10, 20, 30, 40]`, the middle values are 20 and 30. You should return **20**.
#
# ---
#
# ### Engineering Hints
#
# * **The Sorting Trap**: Research the difference between the `.sort()` method and the `sorted()` function in Python. One changes your data forever; the other leaves it exactly as you found it.
# * **The Index Math**: To find the middle index for both odd and even lists, try using this specific formula:
#     `index = (length_of_list - 1) // 2`
#     * *Note: The `//` operator is "floor division." It divides and rounds down to the nearest whole number.*
#
#
#
# ---
#
# ### Test Cases
# Use these examples to verify your code works as expected:
#
# | Input List | Expected Output | Reason |
# | :--- | :--- | :--- |
# | `[5, 2, 9, 1, 7]` | `5` | Odd length; exact middle after sorting. |
# | `[40, 10, 30, 20]` | `20` | Even length; the lower of the two middle values. |
# | `[]` | *Your error message* | The "Empty List" edge case. |
#
# ---
#
# ### Final Check
# After you finish, print your original list *after* calling the function. If the original list is now sorted, you have a **side effect**! A professional function should leave the input data exactly as it was provided.

# %%
def get_median(data):
    """
    Finds the middle value of a list of numbers.
    
    If the list has an odd number of items (like 3 or 5), we pick the middle one.
    If the list has an even number of items (like 4 or 6), we pick the lower 
    of the two middle values.
    """
    # Step 1: Check if the list is empty and return an error message if it is
    
    # Step 2: Create a sorted version of the list 
    # (Hint: Use a tool that creates a NEW list so the original stays the same!)
    
    # Step 3: Find the middle index using (length - 1) // 2
    
    # Step 4: Return the value at that middle index
    pass

# --- Test your code here.  DO NOT EDIT BELOW ---
from tests.test_median import run_all_tests
run_all_tests(get_median)
# Out:
# ✅ Empty List passed
# ❌ Odd Length failed (expected 2, got None)
# ❌ Even Length failed (expected 2, got None)
